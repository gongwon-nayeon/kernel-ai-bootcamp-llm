# %% [markdown]
# # **01 LangChain 기초**
#
# ### 학습 내용
# 1. Chat Models 초기화 및 사용법
# 2. 모델 invocation 방식 (invoke, stream, batch)
# 3. Messages의 구조와 타입 이해
# 4. 대화 기록 관리
# 5. 토큰 사용량 추적

# %% [markdown]
# ## 1. 환경 변수 설정
#
# - OpenAI API Key 발급: https://platform.openai.com/api-keys

# %%
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("API Key가 설정되었습니다.")
# Out:
# API Key가 설정되었습니다.

# %% [markdown]
# **LangChain**은 LLM을 활용한 애플리케이션을 쉽게 개발할 수 있도록 도와주는 프레임워크입니다.
#
# ### 핵심 구성 요소
#
# 1. **Models** - LLM, Chat Models, Embeddings
# 2. **Prompts** - 프롬프트 템플릿과 관리
# 3. **Chains** - 여러 컴포넌트를 연결
# 4. **Memory** - 대화 기록 관리
# 5. **Agents** - 도구를 사용하여 작업 수행

# %% [markdown]
# ## 2. Chat Models(LLM) 기본 사용법
#
# LangChain v1에서는 두 가지 방법으로 Chat Model을 초기화할 수 있습니다:
#
# ### 방법 1: `init_chat_model()`
#
# `init_chat_model()`은 여러 제공자의 모델을 통일된 방식으로 초기화하는 가장 쉬운 방법입니다.
#
# 참고: https://docs.langchain.com/oss/python/langchain/models

# %%
# 방법 1: init_chat_model() 사용
from langchain.chat_models import init_chat_model

# 모델 이름만으로 간단하게 초기화
model = init_chat_model(
    "gpt-4o-mini",  # 또는 "gpt-4o", "claude-sonnet-4-5-20250929" 등
    temperature=0.7,  # 0.0 (결정적) ~ 1.0 (창의적)
    max_tokens=1000,  # 최대 출력 토큰 수
)

# 간단한 질문 실행
response = model.invoke("LangChain의 주요 장점 3가지를 알려주세요.")
print(response.content)
# Out:
# LangChain의 주요 장점은 다음과 같습니다:
#
# 1. **모듈화 및 유연성**: LangChain은 다양한 구성 요소를 모듈화된 방식으로 제공하여 사용자가 필요에 따라 기능을 조합하고 확장할 수 있게 합니다. 이를 통해 특정 애플리케이션의 요구 사항에 맞게 쉽게 조정할 수 있습니다.
#
# 2. **다양한 데이터 소스 통합**: LangChain은 여러 데이터 소스와의 통합을 지원하여 사용자가 다양한 형식의 데이터를 활용할 수 있도록 합니다. 예를 들어, 데이터베이스, API, 파일 시스템 등에서 데이터를 가져와 처리할 수 있습니다.
#
# 3. **강력한 추론 및 대화 기능**: LangChain은 자연어 처리(NLP)와 관련된 다양한 기능을 제공하여, 사용자와의 상호작용을 보다 자연스럽고 효율적으로 만들어줍니다. 이는 챗봇, 질문 응답 시스템 등에서 강력한 성능을 발휘합니다.
#
# 이러한 장점들은 LangChain을 다양한 AI 기반 애플리케이션 개발에 유용한 도구로 만들어 줍니다.

# %% [markdown]
# ### 주요 모델 파라미터
#
# | 파라미터 | 설명 | 기본값 |
# |---------|------|--------|
# | `model` | 사용할 모델 이름 (예: "gpt-4o-mini") | 필수 |
# | `temperature` | 출력의 무작위성 (0.0=결정적, 1.0=창의적) | 모델별 상이 |
# | `max_tokens` | 최대 출력 토큰 수 | 모델별 상이 |
# | `timeout` | API 요청 타임아웃 (초) | 없음 |
# | `max_retries` | 실패 시 재시도 횟수 (지수 백오프 적용) | 6 |

# %% [markdown]
# ### 방법 2: 직접 클래스 사용
#
# `ChatOpenAI`를 직접 import하여 사용할 수도 있습니다. 제공자별 특화 기능이 필요한 경우 유용합니다.

# %%
# 방법 2: ChatOpenAI 직접 사용
from langchain_openai import ChatOpenAI

# ChatOpenAI 모델 초기화 (OpenAI 특화 기능 필요 시)
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    max_tokens=1000,
)

response = llm.invoke("LangChain의 주요 장점 3가지를 알려주세요.")
print(response.content)
# Out:
# LangChain의 주요 장점은 다음과 같습니다:
#
# 1. **모듈화 및 확장성**: LangChain은 다양한 구성 요소들로 모듈화되어 있어, 사용자가 필요에 따라 기능을 추가하거나 수정할 수 있습니다. 이는 개발자가 특정 요구 사항에 맞게 시스템을 손쉽게 조정할 수 있게 해줍니다.
#
# 2. **다양한 데이터 소스 통합**: LangChain은 여러 데이터 소스와의 통합을 지원하여, 사용자가 다양한 형식의 데이터를 쉽게 활용할 수 있도록 합니다. 이를 통해 보다 풍부하고 유용한 정보를 제공할 수 있습니다.
#
# 3. **고급 자연어 처리 기능**: LangChain은 최신 자연어 처리(NLP) 기술을 활용하여, 텍스트 생성, 요약, 질의 응답 등 다양한 작업을 수행할 수 있습니다. 이를 통해 사용자는 보다 자연스럽고 효과적인 대화형 애플리케이션을 구축할 수 있습니다.
#
# 이러한 장점들 덕분에 LangChain은 개발자와 기업들이 AI 기반 애플리케이션을 구축하는 데 매우 유용한 도구로 자리잡고 있습니다.

# %% [markdown]
# ## 3. 메시지(Messages) 이해하기
#
# **메시지(Message)** 는 LangChain에서 모델과 대화하기 위한 기본 단위입니다.
#
# ### 3-1. 메시지의 구성 요소
#
# 1. **Role (역할)** - 메시지 타입 식별 (`system`, `user`)
# 2. **Content (내용)** - 실제 메시지 내용
# 3. **Metadata (메타데이터)** - 선택적 필드 (ID, 이름, 토큰 사용량 등)

# %%
conversation = [
    {"role": "system", "content": "You are a helpful assistant that translates English to French."},
    {"role": "user", "content": "Translate: I love programming."},
    {"role": "assistant", "content": "J'adore la programmation."},
    {"role": "user", "content": "Translate: I love building applications."}
]

response = model.invoke(conversation)
print(response)  # AIMessage("J'adore créer des applications.")
# Out:
# content="J'adore créer des applications." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 48, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ca3e7d71bf', 'id': 'chatcmpl-DNXDzJBuesEkFHYTe0kJj18v3P4YI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d288a-06b0-7dc3-9d26-d882511b3c8d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 48, 'output_tokens': 6, 'total_tokens': 54, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ### 3-2. 텍스트 프롬프트 vs 메시지 프롬프트
#
# | 구분 | 텍스트 프롬프트 | 메시지 프롬프트 |
# |-----|--------------|---------------|
# | 형식 | 문자열 | Message 객체 또는 딕셔너리 리스트 |
# | 사용 시기 | 단순한 1회성 요청 | 대화 기록 관리, 멀티모달 콘텐츠 |
# | 대화 기록 | 불가능 | 가능 |
#
# 참고: https://docs.langchain.com/oss/python/langchain/messages

# %% [markdown]
# **텍스트 프롬프트:**
# ```python
# response = model.invoke("Write a haiku about spring")
# ```

# %% [markdown]
# **메시지 프롬프트:**
# ```python
# from langchain.messages import SystemMessage, HumanMessage, AIMessage
#
# messages = [
#     SystemMessage("You are a poetry expert"),
#     HumanMessage("Write a haiku about spring"),
#     AIMessage("Cherry blossoms bloom...")
# ]
# response = model.invoke(messages)
# ```

# %% [markdown]
# ### 3-3. 메시지 타입 (Message Types)
#
# LangChain은 4가지 주요 메시지 타입을 제공합니다:
#
# **1) SystemMessage - 시스템 지시사항**
# - 모델의 행동과 역할을 정의합니다. 대화의 맥락과 가이드라인을 설정합니다.
#
# **2) HumanMessage - 사용자 입력**
# - 사용자의 질문이나 요청을 나타냅니다. 텍스트, 이미지, 오디오 등 멀티모달 콘텐츠를 포함할 수 있습니다.
#
# **3) AIMessage - AI 응답**
# - 모델이 생성한 응답입니다. 텍스트 외에도 tool_calls, usage_metadata 등의 메타데이터를 포함합니다.
#
# **4) ToolMessage - 도구 실행 결과**
# - Tool 호출의 결과를 모델에 전달할 때 사용합니다.

# %%
# 텍스트 프롬프트 (단순한 문자열)
response = llm.invoke("AI 에이전트란 무엇인가요?")
print("=== 텍스트 프롬프트 ===")
print(response.content)
print(f"응답 타입: {type(response)}")
print()

# 메시지 프롬프트 (대화 기록 포함)
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage("당신은 반말로 대답하는 AI 어시스턴트입니다."),
    HumanMessage("AI 에이전트란 무엇인가요?")
]
response = llm.invoke(messages)
print("=== 메시지 프롬프트 ===")
print(response.content)
print(f"응답 타입: {type(response)}")
# Out:
# === 텍스트 프롬프트 ===
# AI 에이전트란 특정 작업을 수행하거나 문제를 해결하기 위해 설계된 인공지능 시스템을 의미합니다. 이러한 에이전트는 주어진 환경에서 자율적으로 행동하며, 입력 데이터를 분석하고 그에 따른 결정을 내리는 능력을 갖추고 있습니다.
#
# AI 에이전트는 다양한 형태로 존재할 수 있습니다. 예를 들어:
#
# 1. **지능형 개인 비서**: Siri, Google Assistant와 같은 음성 인식 시스템은 사용자와 상호작용하며 정보를 제공하거나 작업을 수행합니다.
#
# 2. **추천 시스템**: Netflix나 Amazon과 같은 플랫폼에서 사용자에게 맞춤형 콘텐츠나 제품을 추천하는 알고리즘도 AI 에이전트의 일종입니다.
#
# 3. **로봇**: 자율주행차나 산업용 로봇은 센서를 통해 환경을 인식하고, 그에 따라 자율적으로 움직이거나 작업을 수행합니다.
#
# 4. **게임 AI**: 비디오 게임에서 NPC(Non-Playable Character)가 플레이어와 상호작용하거나 게임 환경에 반응하는 방식도 AI 에이전트의 한 형태입니다.
#
# AI 에이전트는 일반적으로 목표 지향적이며, 환경에 대한 인식을 바탕으로 행동을 조정하고 학습할 수 있는 능력을 갖추고 있습니다. 이를 통해 더 나은 의사결정을 내리거나 효율적인 작업 수행이 가능합니다.
# 응답 타입: <class 'langchain_core.messages.ai.AIMessage'>
#
# === 메시지 프롬프트 ===
# AI 에이전트는 특정 작업을 수행하기 위해 설계된 인공지능 시스템이야. 보통 데이터를 분석하거나, 문제를 해결하거나, 사용자와 상호작용하는 등의 역할을 해. 예를 들어, 챗봇이나 자동화된 추천 시스템 같은 것들이 AI 에이전트의 일종이지. 이들은 환경에 따라 스스로 학습하고 적응할 수 있는 기능을 갖추고 있어.
# 응답 타입: <class 'langchain_core.messages.ai.AIMessage'>

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# SystemMessage 예제 - 상세한 페르소나 설정
system_msg = SystemMessage("""
당신은 10년 경력의 시니어 Python 개발자입니다.
항상 코드 예제를 제공하고 설명의 근거를 제시하세요.
간결하면서도 철저한 설명을 제공하세요.
""")

messages = [
    system_msg,
    HumanMessage(content="Python의 리스트 컴프리헨션에 대해 설명해주세요.")
]

response = llm.invoke(messages)
print(response.content)
print()
# Out:
# 리스트 컴프리헨션(List Comprehension)은 Python에서 리스트를 간결하고 효율적으로 생성하는 방법입니다. 이는 기존의 리스트에서 요소를 필터링하고 변형하는 과정을 한 줄의 코드로 표현할 수 있게 해줍니다. 기본적인 구조는 다음과 같습니다:
#
# ```python
# [expression for item in iterable if condition]
# ```
#
# ### 구성 요소
# 1. **expression**: 각 요소에 적용할 표현식입니다. 이 표현식은 최종 리스트의 요소가 됩니다.
# 2. **item**: iterable 객체(리스트, 튜플 등)에서 요소를 나타냅니다.
# 3. **iterable**: 반복 가능한 객체입니다.
# 4. **condition** (선택 사항): 요소를 포함할지 여부를 결정하는 조건문입니다.
#
# ### 예제
# 아래는 0부터 9까지의 숫자의 제곱을 포함하는 리스트를 생성하는 예제입니다.
#
# ```python
# squares = [x**2 for x in range(10)]
# print(squares)
# ```
#
# **출력**:
# ```
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# 여기서 `x**2`는 각 숫자의 제곱을 계산하는 표현식입니다. `for x in range(10)`은 0부터 9까지의 숫자를 반복합니다.
#
# ### 조건문 사용 예제
# 조건문을 추가하여 짝수의 제곱만 포함하는 리스트를 생성할 수 있습니다.
#
# ```python
# even_squares = [x**2 for x in range(10) if x % 2 == 0]
# print(even_squares)
# ```
#
# **출력**:
# ```
# [0, 4, 16, 36, 64]
# ```
#
# 여기서 `if x % 2 == 0`는 x가 짝수인 경우에만 그 제곱을 포함하도록 필터링합니다.
#
# ### 장점
# - **가독성**: 코드를 간결하게 만들어 가독성을 높입니다.
# - **성능**: 리스트 컴프리헨션은 일반적인 루프보다 성능이 좋습니다, Python의 내부 최적화 덕분입니다.
#
# ### 결론
# 리스트 컴프리헨션은 Python에서 리스트를 생성할 때 매우 유용한 기능입니다. 이를 통해 코드의 길이를 줄이고, 가독성을 높이며, 성능을 향상시킬 수 있습니다.

# %%
# AIMessage를 수동으로 생성하여 대화 기록 구성
conversation = [
    SystemMessage("당신은 도움이 되는 AI 어시스턴트입니다."),
    HumanMessage("도와주실 수 있나요?"),
    AIMessage("물론입니다! 기꺼이 도와드리겠습니다."),  # 수동으로 추가한 AI 응답
    HumanMessage("2+2는 얼마인가요?")
]

response = llm.invoke(conversation)
print("=== 수동으로 구성한 대화 기록 ===")
print(f"최종 응답: {response.content}")
print("\n전체 대화:")
for i, msg in enumerate(conversation + [response], 1):
    print(f"{i}. [{msg.type}] {msg.content}")
# Out:
# === 수동으로 구성한 대화 기록 ===
# 최종 응답: 2 + 2는 4입니다.
#
# 전체 대화:
# 1. [system] 당신은 도움이 되는 AI 어시스턴트입니다.
# 2. [human] 도와주실 수 있나요?
# 3. [ai] 물론입니다! 기꺼이 도와드리겠습니다.
# 4. [human] 2+2는 얼마인가요?
# 5. [ai] 2 + 2는 4입니다.

# %% [markdown]
# ### 3-4. 메시지 메타데이터 설정

# %%
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
human_msg
# Out:
# HumanMessage(content='Hello!', additional_kwargs={}, response_metadata={}, name='alice', id='msg_123')

# %% [markdown]
# ### 📖 과제 1: 시스템 프롬프트로 챗봇의 역할 정의하기
# SystemMessage로 시스템 프롬프트(페르소나, 역할, 규칙 등 정의)를 작성하고 답변 받아보기

# %%
# CODE HERE

# %% [markdown]
# ## 4. 대화 기록 관리
#
# Chat Models는 기본적으로 stateless입니다. 대화 맥락을 유지하려면 메시지 리스트를 직접 관리해야 합니다.
#
# ### 대화 기록 관리 방법
#
# 1. 메시지 리스트에 HumanMessage 추가
# 2. 모델 호출
# 3. 반환된 AIMessage를 리스트에 추가
# 4. 다음 호출 시 전체 리스트 전달

# %%
# 대화 기록을 메시지 리스트로 관리
chat_history = []

# 첫 번째 대화
print("=== 대화 1 ===")
user_msg_1 = HumanMessage(content="제 이름은 민수입니다.")
chat_history.append(user_msg_1)

response_1 = llm.invoke(chat_history)
print(f"User: {user_msg_1.content}")
print(f"AI: {response_1.content}")

# AI 응답을 대화 기록에 추가
chat_history.append(response_1)

# 두 번째 대화
print("\n=== 대화 2 ===")
user_msg_2 = HumanMessage(content="제 이름이 뭐라고 했죠?")
chat_history.append(user_msg_2)

response_2 = llm.invoke(chat_history)
print(f"User: {user_msg_2.content}")
print(f"AI: {response_2.content}")
chat_history.append(response_2)

# 대화 기록 확인
print(f"\n현재 대화 기록 길이: {len(chat_history)} messages")
for i, msg in enumerate(chat_history, 1):
    print(f"{i}. [{msg.type}] {msg.content}")
# Out:
# === 대화 1 ===
# User: 제 이름은 민수입니다.
# AI: 안녕하세요, 민수님! 만나서 반갑습니다. 어떻게 도와드릴까요?
#
# === 대화 2 ===
# User: 제 이름이 뭐라고 했죠?
# AI: 민수님이라고 하셨습니다! 어떻게 도와드릴까요?
#
# 현재 대화 기록 길이: 4 messages
# 1. [human] 제 이름은 민수입니다.
# 2. [ai] 안녕하세요, 민수님! 만나서 반갑습니다. 어떻게 도와드릴까요?
# 3. [human] 제 이름이 뭐라고 했죠?
# 4. [ai] 민수님이라고 하셨습니다! 어떻게 도와드릴까요?

# %%
# SystemMessage로 역할 설정 + 대화 기록 관리
conversation = [
    SystemMessage(content="당신은 Python 튜터입니다. 초보자에게 친절하게 설명하세요."),
    HumanMessage(content="변수란 무엇인가요?"),
]

response = llm.invoke(conversation)
print("=== 역할이 설정된 대화 ===")
print(f"AI: {response.content}\n")

# 대화 이어가기
conversation.append(response)
conversation.append(HumanMessage(content="예제를 보여주세요."))

response = llm.invoke(conversation)
print("=== 이어진 대화 ===")
print(f"AI: {response.content}")
# Out:
# === 역할이 설정된 대화 ===
# AI: 변수는 프로그래밍에서 데이터를 저장하는 "상자"라고 생각하면 됩니다. 우리가 변수를 사용하면 데이터를 기억하고, 필요할 때 쉽게 꺼내 쓸 수 있습니다.
#
# 예를 들어, 당신이 친구의 나이를 저장하고 싶다고 가정해봅시다. 그 나이를 변수에 저장하면, 나중에 그 값을 다시 사용할 수 있습니다. Python에서는 변수를 다음과 같이 만들 수 있습니다:
#
# ```python
# age = 25
# ```
#
# 여기서 `age`는 변수의 이름이고, `25`는 그 변수에 저장된 값입니다. 이제 `age`라는 변수를 사용해서 나이를 참조할 수 있습니다. 예를 들어, 아래와 같이 출력할 수 있습니다:
#
# ```python
# print(age)
# ```
#
# 이 코드를 실행하면, 화면에 `25`가 출력됩니다.
#
# 변수의 이름은 의미 있는 것으로 정하는 것이 좋습니다. 예를 들어, 친구의 이름을 저장하고 싶다면 `friend_name`이라는 변수를 만들 수 있습니다:
#
# ```python
# friend_name = "John"
# print(friend_name)
# ```
#
# 이렇게 하면 "John"이라는 이름이 출력됩니다.
#
# 변수는 우리가 프로그램을 만들 때 데이터를 저장하고 조작하는 데 매우 중요한 역할을 합니다. 다양한 데이터 타입(숫자, 문자열, 리스트 등)을 변수에 저장할 수 있으며, 이를 통해 프로그램의 동작을 유연하게 만들 수 있습니다.
#
# === 이어진 대화 ===
# AI: 물론입니다! 간단한 예제를 통해 변수를 사용하는 방법을 보여드리겠습니다. 이 예제는 두 개의 숫자를 더하고, 친구의 이름과 나이를 출력하는 프로그램입니다.
#
# ```python
# # 변수에 숫자 저장하기
# number1 = 10
# number2 = 20
#
# # 두 숫자를 더하기
# sum_result = number1 + number2
#
# # 결과 출력하기
# print("두 숫자의 합은:", sum_result)
#
# # 친구의 이름과 나이 저장하기
# friend_name = "Alice"
# friend_age = 30
#
# # 친구의 정보 출력하기
# print("친구의 이름은:", friend_name)
# print("친구의 나이는:", friend_age)
# ```
#
# ### 이 코드의 설명:
#
# 1. **숫자를 변수에 저장**: `number1`과 `number2`라는 변수에 각각 10과 20을 저장합니다.
# 2. **덧셈 수행**: `sum_result`라는 변수에 `number1`과 `number2`를 더한 값을 저장합니다.
# 3. **결과 출력**: `print()` 함수를 사용하여 두 숫자의 합을 출력합니다.
# 4. **친구의 정보 저장**: `friend_name` 변수에 "Alice"라는 이름을, `friend_age` 변수에 30이라는 나이를 저장합니다.
# 5. **친구의 정보 출력**: `print()` 함수를 사용하여 친구의 이름과 나이를 출력합니다.
#
# 이 코드를 실행하면 다음과 같은 결과가 출력됩니다:
#
# ```
# 두 숫자의 합은: 30
# 친구의 이름은: Alice
# 친구의 나이는: 30
# ```
#
# 이 예제를 통해 변수를 어떻게 사용하고, 데이터를 저장하고, 출력하는지 이해하는 데 도움이 되었기를 바랍니다! 추가적인 질문이 있다면 언제든지 물어보세요.

# %% [markdown]
# ### 📖 과제 2: 멀티턴
# 1. SystemMessage로 "당신은 여행 가이드입니다"로 역할 설정
# 2. 사용자가 "일본 여행을 가려고 해요" 질문
# 3. AI 응답 받기
# 4. 이어서 "어디를 추천하나요?" 질문
# 5. 전체 대화 기록 출력

# %%
# CODE HERE

# %% [markdown]
# ## 5. 스트리밍 (Streaming)
#
# ### 5-1. AIMessageChunk
#
# - `invoke()`는 하나의 `AIMessage`를 반환
# - `stream()`은 여러 개의 `AIMessageChunk`를 반환
# - 각 청크는 출력 텍스트의 일부를 포함
# - 더하기 연산으로 전체 메시지를 구성 가능

# %%
# 방법 1: 텍스트만 스트리밍
for chunk in llm.stream("Python의 장점을 간단히 설명해주세요."):
    print(chunk.text, end="", flush=True)
print("\n")
# Out:
# Python의 장점은 다음과 같습니다:
#
# 1. **간결하고 가독성 높은 문법**: Python은 코드가 직관적이고 읽기 쉬워서, 배우기 쉽고 유지보수하기 용이합니다.
#
# 2. **다양한 라이브러리와 프레임워크**: 데이터 분석, 웹 개발, 머신러닝 등 다양한 분야에서 사용할 수 있는 풍부한 라이브러리(예: NumPy, Pandas, Flask, Django 등)가 제공됩니다.
#
# 3. **다양한 플랫폼 지원**: Windows, macOS, Linux 등 다양한 운영체제에서 실행할 수 있으며, 크로스 플랫폼 개발이 용이합니다.
#
# 4. **활발한 커뮤니티**: 방대한 사용자와 개발자 커뮤니티가 있어, 문제 해결에 대한 지원과 다양한 자료를 쉽게 찾을 수 있습니다.
#
# 5. **빠른 프로토타이핑**: 코드 작성 속도가 빠르고, 실험과 테스트가 용이해 아이디어를 신속하게 구현할 수 있습니다.
#
# 6. **객체 지향 프로그래밍 지원**: Python은 객체 지향 프로그래밍을 지원하여 코드의 재사용성과 구조화를 촉진합니다.
#
# 이러한 장점들 덕분에 Python은 다양한 분야에서 널리 사용되고 있습니다.

# %% [markdown]
# ### 5-2. AIMessageChunk 누적하기
#
# 스트리밍 중에 청크를 누적하여 전체 AIMessage를 구성할 수 있습니다. 누적된 메시지는 `invoke()`로 받은 메시지와 동일하게 사용할 수 있습니다.

# %%
# 방법 2: AIMessageChunk 누적하여 전체 메시지 구성
print("=== 청크 누적 방식 ===")
full_message = None

for chunk in llm.stream("파이썬이란 무엇인가요?"):
    # 청크를 더하기 연산으로 누적
    full_message = chunk if full_message is None else full_message + chunk
    print(chunk.text, end="", flush=True)

print(f"\n\n최종 메시지 타입: {type(full_message)}")
print(f"최종 메시지 content: {full_message.content}")
# Out:
# === 청크 누적 방식 ===
# 파이썬(Python)은 고급 프로그래밍 언어로, 1991년에 귀도 반 로썸(Guido van Rossum)에 의해 처음 개발되었습니다. 파이썬은 코드의 가독성이 뛰어나고, 문법이 간결하여 배우기 쉽고 사용하기 편리한 언어로 널리 알려져 있습니다.
#
# 파이썬의 주요 특징은 다음과 같습니다:
#
# 1. **가독성**: 파이썬은 코드의 가독성을 중요시하여, 명확하고 간결한 문법을 제공합니다. 이는 개발자들이 코드를 더 쉽게 이해하고 유지보수할 수 있도록 돕습니다.
#
# 2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능, 머신러닝, 게임 개발, 자동화 스크립트 등 다양한 분야에서 사용될 수 있습니다.
#
# 3. **풍부한 라이브러리**: 파이썬은 다양한 표준 라이브러리와 서드파티 라이브러리가 있어, 개발자가 많은 기능을 쉽게 구현할 수 있도록 지원합니다. 예를 들어, 데이터 분석을 위한 Pandas, 과학 계산을 위한 NumPy, 웹 개발을 위한 Django와 Flask 등이 있습니다.
#
# 4. **크로스 플랫폼**: 파이썬은 Windows, macOS, Linux 등 다양한 운영체제에서 실행될 수 있습니다.
#
# 5. **대화형 프로그래밍**: 파이썬은 대화형 모드에서 코드를 실행할 수 있어, 빠르게 테스트하고 디버깅할 수 있는 환경을 제공합니다.
#
# 이러한 이유로 파이썬은 초보자부터 전문가까지 널리 사용되는 인기 있는 프로그래밍 언어입니다.
#
# 최종 메시지 타입: <class 'langchain_core.messages.ai.AIMessageChunk'>
# 최종 메시지 content: 파이썬(Python)은 고급 프로그래밍 언어로, 1991년에 귀도 반 로썸(Guido van Rossum)에 의해 처음 개발되었습니다. 파이썬은 코드의 가독성이 뛰어나고, 문법이 간결하여 배우기 쉽고 사용하기 편리한 언어로 널리 알려져 있습니다.
#
# 파이썬의 주요 특징은 다음과 같습니다:
#
# 1. **가독성**: 파이썬은 코드의 가독성을 중요시하여, 명확하고 간결한 문법을 제공합니다. 이는 개발자들이 코드를 더 쉽게 이해하고 유지보수할 수 있도록 돕습니다.
#
# 2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능, 머신러닝, 게임 개발, 자동화 스크립트 등 다양한 분야에서 사용될 수 있습니다.
#
# 3. **풍부한 라이브러리**: 파이썬은 다양한 표준 라이브러리와 서드파티 라이브러리가 있어, 개발자가 많은 기능을 쉽게 구현할 수 있도록 지원합니다. 예를 들어, 데이터 분석을 위한 Pandas, 과학 계산을 위한 NumPy, 웹 개발을 위한 Django와 Flask 등이 있습니다.
#
# 4. **크로스 플랫폼**: 파이썬은 Windows, macOS, Linux 등 다양한 운영체제에서 실행될 수 있습니다.
#
# 5. **대화형 프로그래밍**: 파이썬은 대화형 모드에서 코드를 실행할 수 있어, 빠르게 테스트하고 디버깅할 수 있는 환경을 제공합니다.
#
# 이러한 이유로 파이썬은 초보자부터 전문가까지 널리 사용되는 인기 있는 프로그래밍 언어입니다.

# %% [markdown]
# ### 📖 과제 3: 스트리밍으로 긴 설명 받기
# "인공지능의 역사를 상세히 설명해주세요"를 stream()으로 처리하고,
# 청크가 올 때마다 화면에 출력하세요.

# %%
# CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ### 참고 자료
#
# - [LangChain Models 공식 문서](https://docs.langchain.com/oss/python/langchain/models)
# - [LangChain Messages 공식 문서](https://docs.langchain.com/oss/python/langchain/messages)
# - [Chat Models 통합 가이드](https://docs.langchain.com/oss/python/integrations/chat)
